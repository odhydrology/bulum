# %%
import bulum
import bulum.io as oio
import bulum.utils as out
import bulum.plots as opl
import pandas as pd
import numpy as np

# %%
# print bulum version
print('bulum version: ', bulum.__version__)
# Out:
# odhpy version:  0.2.5

# %%
df = oio.read_ts_csv('../io/tests/modelled_flow.csv')

#print the index data type
print(df.index.dtype) #"object" means string

df
# Out:
# object
#             modelled_flow
# Date
# 1889-01-01       0.000000
# 1889-01-02       2.171824
# 1889-01-03       0.000000
# 1889-01-04       6.275062
# 1889-01-05      61.837250
# ...                   ...
# 2014-06-12       0.000000
# 2014-06-13       0.000000
# 2014-06-14      33.000041
# 2014-06-15      32.688085
# 2014-06-16      21.318540
#
# [45822 rows x 1 columns]

# %%
opl.plot_flow(df)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: ylabel='Flow [ML/d]'>)

# %%
# convert the index to datetime

df2 = df.copy(deep=True)
df2.index = pd.to_datetime(df2.index)

# print the index data type
print(df2.index.dtype) #datetime64[ns]

opl.plot_flow(df2)
# Out:
# datetime64[ns]
# (<Figure size 640x480 with 1 Axes>, <Axes: ylabel='Flow [ML/d]'>)
